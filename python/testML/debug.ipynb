# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# สมมติว่าข้อมูลกราฟของคุณมีลักษณะดังนี้
# graphs เป็น numpy array ที่มี shape (จำนวนกราฟ, จำนวนจุดในแต่ละกราฟ, จำนวนคุณลักษณะต่อจุด)
# ในตัวอย่างนี้, สมมติว่ามี 1 คุณลักษณะต่อจุดคือค่า y
# y_labels เป็นความหวานของน้ำตาลสำหรับแต่ละกราฟ

# ตัวอย่างข้อมูล
graphs = np.random.rand(1000, 10000, 1)  # 100 กราฟ, แต่ละกราฟมี 10 จุด, 1 คุณลักษณะ (ค่า y)
y_labels = np.random.rand(1000, 1)  # ความหวานของน้ำตาลสำหรับแต่ละกราฟ

# สร้างโมเดล LSTM
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(10000, 1)))  # 50 ยูนิต LSTM, จุดข้อมูล 10 จุด, 1 คุณลักษณะ
model.add(Dense(1))  # ชั้นเอาต์พุตมี 1 ยูนิตสำหรับทำนายความหวานของน้ำตาล

# คอมไพล์โมเดล
model.compile(optimizer='adam', loss='mean_squared_error')

# ฝึกโมเดล
model.fit(graphs, y_labels, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 23
#      20 model.compile(optimizer='adam', loss='mean_squared_error')
#      22 # ฝึกโมเดล
# ---> 23 model.fit(graphs, y_labels, epochs=100, batch_size=32)
#
# File c:\Users\User\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
graphs
# Out:
# array([[[0.16041995],
#         [0.15676633],
#         [0.21838656],
#         ...,
#         [0.07076161],
#         [0.82228806],
#         [0.14950483]],
#
#        [[0.24982657],
#         [0.40370982],
#         [0.87054485],
#         ...,
#         [0.7411755 ],
#         [0.34789558],
#         [0.30759739]],
#
#        [[0.03204614],
#         [0.78352889],
#         [0.30470901],
#         ...,
#         [0.05813959],
#         [0.82611514],
#         [0.11399545]],
#
#        ...,
#
#        [[0.3098894 ],
#         [0.21403296],
#         [0.49702614],
#         ...,
#         [0.39201786],
#         [0.75069821],
#         [0.84699067]],
#
#        [[0.05599742],
#         [0.55622956],
#         [0.91927584],
#         ...,
#         [0.55918769],
#         [0.17683544],
#         [0.02666668]],
#
#        [[0.18845737],
#         [0.67957423],
#         [0.99296507],
#         ...,
#         [0.1713222 ],
#         [0.08156951],
#         [0.26207585]]])

# %%
y_labels
# Out:
# array([[5.12712038e-01],
#        [7.42306067e-02],
#        [6.22184764e-02],
#        [4.31238794e-01],
#        [1.32409933e-01],
#        [9.01355760e-01],
#        [1.48842090e-01],
#        [6.86424616e-01],
#        [2.35018980e-01],
#        [5.81357907e-01],
#        [1.09116280e-01],
#        [3.74114038e-04],
#        [4.93994886e-01],
#        [5.36352918e-01],
#        [3.06230433e-01],
#        [4.55309818e-01],
#        [8.77023559e-01],
#        [4.56296815e-02],
#        [6.86448134e-01],
#        [2.44648816e-01],
#        [6.30357591e-01],
#        [1.08062419e-02],
#        [1.91852429e-01],
#        [6.47682401e-01],
#        [9.86175528e-01],
#        [9.87223691e-01],
#        [2.05712884e-01],
#        [6.91737646e-01],
#        [8.15851576e-01],
#        [4.31873815e-02],
#        [2.92094738e-02],
#        [4.59980581e-01],
#        [1.82161273e-01],
#        [7.00479897e-01],
#        [4.03896877e-01],
#        [8.34031722e-01],
#        [3.45850384e-01],
# ...
